# %%
import pandas as pd
df = pd.read_csv('pokemon-spawns.csv')
df = df[5546:6789]
df
# Out:
#                     s2_id     s2_token  num      name        lat         lng  \
# 5546 -9182915535501787000  808fbaf930f   48   Venonat  37.433594 -122.132955
# 5547 -9182915522616885000  808fbafc0bd   16    Pidgey  37.433354 -122.135972
# 5548 -9182915537649271000  808fbaf896b   19   Rattata  37.433453 -122.130205
# 5549 -9182916259203777000  808fba50cbb  129  Magikarp  37.433602 -122.123284
# 5550 -9182916229139005000  808fba57c81   19   Rattata  37.432681 -122.127809
# ...                   ...          ...  ...       ...        ...         ...
# 6784 -9182943059799704000  808fa1f0eab   16    Pidgey  37.500624 -122.272522
# 6785 -9182943034029900000  808fa1f6d17   16    Pidgey  37.499621 -122.270661
# 6786 -9182943059799704000  808fa1f0ca5   13    Weedle  37.500927 -122.271282
# 6787 -9182943036177383000  808fa1f66b9   41     Zubat  37.499681 -122.267028
# 6788 -9182942892295979000  808fa2178fb   21   Spearow  37.499775 -122.253469
#
#        encounter_ms    disppear_ms
# ...

# %%
import folium
map = folium.Map(
    location = [df['lat'][6787],df['lng'][6787]],
    zoom_start=12,
    tiles = 'openstreetmap'
)

for i in range(len(df)):
    asd = i+5546
    icon_url = f"https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/{df['num'][asd]}.png"
    icon = folium.features.CustomIcon(icon_url,icon_size=(50, 50))
    folium.Marker(
    location=[df['lat'][asd],df['lng'][asd]],
    icon = icon,
    tooltip=f"<img src=https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/{df['num'][asd]}.png></img"
    ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
